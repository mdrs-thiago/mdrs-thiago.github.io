# %% [markdown]
# # Exemplo Prático: HuggingFace & BERT
#
# Este é um notebook de referência para uso de pipelines e modelos do HuggingFace Hub, preparado para a disciplina de Tópicos Especiais A.

# %%
# pip install transformers torch
